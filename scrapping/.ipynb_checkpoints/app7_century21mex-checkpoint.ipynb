# %%
#Get the first page to extract page numbers
import requests, re
from bs4 import BeautifulSoup

r=requests.get("https://century21mexico.com/departamento/venta/Ciudad-De-Mexico/Benito-Ju%C3%A1rez")
c=r.content

# %%
soup=BeautifulSoup(c,"html.parser")

all=soup.find_all("div",{"col-md-6 col-lg-4 mb-3"})

float(all[0].find("h5",{"class":"h6 card-title precio family-typoldBold rGold"}).text.replace("\n","").replace(" ","").replace("$","").replace(",","").split("MXN")[0]
     )
all[0].find("span",{"class":"family-oakesReg"}).text.split("\n")[0]
all[0].find("span",{"class":"family-oakesReg"}).text.split("\n")[1]
all[0].find("span",{"class":"family-oakesReg"}).text.split("\n")[2]
all[0].find("span",{"class":"font-weight-bold family-typoldBold"}).text#.split("\n")[2]
all[0].find("div",{"class":"col-4 typoldReg text-right"}).text.replace("\n","").replace(" ","").split("\xa0")[0]
str(all[0].find_all("a")).split("=")[1].split(">")[0]
#"col-4 typoldReg text-right"     

page_nr=int(soup.find_all("a",{"class":"page-link"})[-2].text.split(" ")[0])
#print(page_nr,"number of pages were found")
#soup

# %%
l=[]
base_url="https://century21mexico.com/departamento/venta/Ciudad-De-Mexico/Benito-Ju%C3%A1rez?pagina="
#page=1
for pg in range(page_nr):
    pg=pg+1
    r=requests.get(base_url+str(pg)+".html")
    c=r.content
    soup=BeautifulSoup(c,"html.parser")
    all=soup.find_all("div",{"col-md-6 col-lg-4 mb-3"})
    for item in all:
        d={}
        d['direccion']=str(item.find_all("a")).replace("\n","").split("/")[6].replace("'","").split(">")[0]
        d['Precio']=float(item.find("h5",{"class":"h6 card-title precio family-typoldBold rGold"}).text.replace("\n","").replace(" ","").replace("$","").replace(",","").split("MXN")[0]
         )
        d['colonia']=item.find("span",{"class":"family-oakesReg"}).text.split("\n")[0]
        d['alcaldia']=item.find("span",{"class":"family-oakesReg"}).text.split("\n")[1]
        d['ciudad']=item.find("span",{"class":"family-oakesReg"}).text.split("\n")[2]
        d['Tels']=item.find("span",{"class":"font-weight-bold family-typoldBold"}).text
        d['n_recamaras']=int(item.find("div",{"class":"col-4 typoldReg text-right"}).text.replace("\n","").replace(" ","").split("\xa0")[0])
        d['n_banios']=int(item.find("div",{"class":"col-4 typoldReg text-right"}).text.replace("\n","").replace(" ","").split("\xa0")[1])
        d['n_estacionam']=int(item.find("div",{"class":"col-4 typoldReg text-right"}).text.replace("\n","").replace(" ","").split("\xa0")[2])
        d['Terreno']=int(item.find("div",{"class":"col-4 typoldReg text-right"}).text.replace("\n","").replace(" ","").split("\xa0")[3])
        try:
            d['construccion']=int(item.find("div",{"class":"col-4 typoldReg text-right"}).text.replace("\n","").replace(" ","").split("\xa0")[4])
        except:
            d['construccion']=None

        l.append(d)

# %%
l
# Out:
# [{'Precio': 16500000.0,
#   'Tels': '(55)1107-8717',
#   'Terreno': 410,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 410,
#   'direccion': '299767_SAN-FRANCISCO-657"',
#   'n_banios': 5,
#   'n_estacionam': 2,
#   'n_recamaras': 4},
#  {'Precio': 15500000.0,
#   'Tels': '(55)1251-9900',
#   'Terreno': 370,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Extremadura Insurgentes',
#   'construccion': 370,
#   'direccion': '288732_Exclusivo-departaento-de-2-pisos-en-el-Parque-Hundido"',
#   'n_banios': 4,
#   'n_estacionam': 2,
#   'n_recamaras': 4},
#  {'Precio': 15000000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 188,
#   'direccion': '303935_Departamento-en-venta-en-Nápoles"',
#   'n_banios': 3,
#   'n_estacionam': 4,
#   'n_recamaras': 3},
#  {'Precio': 13845000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 213,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 213,
#   'direccion': '301612_Residencial-Valle-Sur-Nuevo-y-Sofisticado-Penthouse-con-Excelente-Ubicación"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 13400000.0,
#   'Tels': '(55)5277-1888',
#   'Terreno': 259,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'San José Insurgentes',
#   'construccion': 259,
#   'direccion': '289505_Acordada-espectacular-PH-en-venta"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 12000000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 207,
#   'direccion': '305768_Departamento-en-venta-en-Col.-Del-Valle"',
#   'n_banios': 3,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 10100000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 240,
#   'direccion': '258568_Departamento-en-venta%252C-Del-Valle%252C-Benito-Juárez."',
#   'n_banios': 4,
#   'n_estacionam': 3,
#   'n_recamaras': 4},
#  {'Precio': 9966000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 151,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 151,
#   'direccion': '301590_Residencial-Valle-Sur-Nuevo-y-Sofisticado-Departamento-con-Excelente-Ubicación-en-VENTA"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 9660000.0,
#   'Tels': '(55)5550-2880',
#   'Terreno': 331,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 303,
#   'direccion': '302050_Inmejorable-PH-para-actualizar-en-Col.-del-Valle."',
#   'n_banios': 6,
#   'n_estacionam': 2,
#   'n_recamaras': 5},
#  {'Precio': 9045000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 135,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 135,
#   'direccion': '301607_Residencial-Valle-Sur-Nuevo-y-Sofisticado-Departamento-con-Excelente-Ubicación-en-VENTA"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 9040000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 114,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte',
#   'construccion': 114,
#   'direccion': '286071_Elegantes-y-exclusivos-departamentos-en-Preventa"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 8350000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 181,
#   'direccion': '247733_Departamento-en-venta%252C-Del-Valle%252C-Benito-Juárez."',
#   'n_banios': 3,
#   'n_estacionam': 3,
#   'n_recamaras': 3},
#  {'Precio': 8280000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 120,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 120,
#   'direccion': '301586_Residencial-Valle-Sur-Nuevo-y-Sofisticado-Departamento-con-Excelente-Ubicación-en-VENTA"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 8229892.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 230,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Poniente',
#   'construccion': 230,
#   'direccion': '305814_Penthouse-en-VENTA-Narvarte-Poniente%252C-Benito-Juarez"',
#   'n_banios': 2,
#   'n_estacionam': 3,
#   'n_recamaras': 3},
#  {'Precio': 8173000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 109,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte',
#   'construccion': 109,
#   'direccion': '286073_Elegantes-y-exclusivos-departamentos-en-Preventa"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 8142000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 118,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 118,
#   'direccion': '301595_Residencial-Valle-Sur-Nuevo-y-Sofisticado-Departamento-con-Excelente-Ubicación-en-VENTA"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 8044000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 112,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte',
#   'construccion': 112,
#   'direccion': '286072_Elegantes-y-exclusivos-departamentos-en-Preventa"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 7900000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Norte',
#   'construccion': 180,
#   'direccion': '256192_Penthouse-en-venta%252C-Del-Valle%252C-Benito-Juárez."',
#   'n_banios': 3,
#   'n_estacionam': 3,
#   'n_recamaras': 3},
#  {'Precio': 7500000.0,
#   'Tels': '(55)1517-3591 / (55)5421-9381',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 307,
#   'direccion': '282732_Departamento-en-la-Colonia-del-Valle-Centro"',
#   'n_banios': 3,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 7200000.0,
#   'Tels': '(55)3869-1070',
#   'Terreno': 130,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': None,
#   'direccion': '304215_Nápoles.-Hermoso-Departamento"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 7000000.0,
#   'Tels': '(55)2124-8076',
#   'Terreno': 126,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 126,
#   'direccion': '282615_Amplio-departamento-en-Venta-Colonia-Nápoles"',
#   'n_banios': 3,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 6950000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 140,
#   'direccion': '275242_Departamento-en-venta%252C-Del-Valle%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 3,
#   'n_recamaras': 2},
#  {'Precio': 6900000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 156,
#   'direccion': '299013_Departamento-en-venta%252C-Del-Valle%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 6850000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 125,
#   'direccion': '287074_Departamento-en-venta%252C-Del-Valle%252C-Benito-Juárez"',
#   'n_banios': 3,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 6841100.0,
#   'Tels': '(55)5291-1500',
#   'Terreno': 120,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Sur',
#   'construccion': 120,
#   'direccion': '298135_5%25-de-descuento-por-buen-fin-!"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 6500000.0,
#   'Tels': '(55)2124-8076',
#   'Terreno': 88,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Santa Maria Nonoalco',
#   'construccion': 88,
#   'direccion': '285880_Departamento-en-Venta-entre-Patriotismo-y-Revolución"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 6500000.0,
#   'Tels': '(55)5368-5577 / (55)5368-5544',
#   'Terreno': 131,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 131,
#   'direccion': '298845_Departamento-en-Venta%252C-Del-Valle%252C-Benito-Juárez."',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 6470000.0,
#   'Tels': '(55)1107-8717',
#   'Terreno': 94,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 94,
#   'direccion': '281289_DAKOTA-95"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 6400000.0,
#   'Tels': '(55)3869-1070',
#   'Terreno': 180,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': None,
#   'direccion': '294812_Del-Valle-Centro-¡Hermoso-departamento!"',
#   'n_banios': 3,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 6335867.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 157,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Poniente',
#   'construccion': 157,
#   'direccion': '305817_Departamento-en-VENTA-en-Narvarte-Benito-Juárez-NUEVO-Estrena!!"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 6200000.0,
#   'Tels': '(55)1107-8717',
#   'Terreno': 144,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 144,
#   'direccion': '300251_XOLA"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 6177000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 112,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte',
#   'construccion': 112,
#   'direccion': '286070_Elegantes-y-exclusivos-departamentos-en-Preventa"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 6045177.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 130,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Poniente',
#   'construccion': 130,
#   'direccion': '305805_Departamento-en--Venta%252C--Narvarte-Poniente%252C-Benito-Juarez."',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 5973450.0,
#   'Tels': '(55)5291-1500',
#   'Terreno': 104,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Sur',
#   'construccion': 104,
#   'direccion': '298165_Aprovecha-un-5%25-de-descuento-por-buen-fin"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 5750000.0,
#   'Tels': '(55)5662-9700',
#   'Terreno': 98,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'San José Insurgentes',
#   'construccion': 98,
#   'direccion': '297078_Departamento-Venta---San-Jose-Insurgentes"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 5694000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 98,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte',
#   'construccion': 98,
#   'direccion': '286065_Elegantes-y-exclusivos-departamentos-en-Preventa"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 5690000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 190,
#   'direccion': '283378_Departamento-en-venta%252C-Del-Valle%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 5625000.0,
#   'Tels': '(55)1517-3591 / (55)5421-9381',
#   'Terreno': 180,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'San Juan',
#   'construccion': 90,
#   'direccion': '304492_Departamento-en-la-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 5600000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Oriente',
#   'construccion': 121,
#   'direccion': '287119_Departamento-en-venta%252C-Narvarte%252C-Benito-Juárez"',
#   'n_banios': 3,
#   'n_estacionam': 2,
#   'n_recamaras': 4},
#  {'Precio': 5300000.0,
#   'Tels': '(55)5662-9700',
#   'Terreno': 284,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nativitas',
#   'construccion': 284,
#   'direccion': '267529_Penth-house-en-Venta"',
#   'n_banios': 3,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 5250000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 120,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Portales Norte',
#   'construccion': 120,
#   'direccion': '305239_Departamento-Nuevo-en-VENTA-en-Narvarte-120-m2%252C-3-recamaras-y-2.5-baños"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 5200000.0,
#   'Tels': '(55)2455-1166 / (55)2455-1167 / (55)2455-1168',
#   'Terreno': 175,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 178,
#   'direccion': '300988_Departamento-en-venta-en-la-Colonia-Del-Valle"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 5100000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 86,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 86,
#   'direccion': '293378_DEPARTAMENTO-EN-VENTA%252C-COL.-NAPOLES%252C-BENITO-JUAREZ"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 5100000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 86,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 86,
#   'direccion': '293443_DEPARTAMENTO-EN-VENTA%252C-COL.-NÁPOLES%252C-BENITO-JUAREZ"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 5100000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 86,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 86,
#   'direccion': '293453_DEPARTAMENTO-EN-VENTA%252C-COL.-NAPOLES%252C-BENITO-JUAREZ"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 5100000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Norte',
#   'construccion': 98,
#   'direccion': '295132_Departamento-en-venta%252C-Del-Valle-Norte%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 5100000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 100,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Insurgentes Mixcoac',
#   'construccion': 100,
#   'direccion': '301271_Excelente-departamento-en-venta"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 5075000.0,
#   'Tels': '(55)5255-5521 con 4 líneas',
#   'Terreno': 113,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nochebuena',
#   'construccion': 113,
#   'direccion': '286779_Venta-Departamento-a-una-cuadra-de-Parque-Hundido-y-a-unas-cuadras-de-Liverpool-Insurgentes.-Excelen"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4980000.0,
#   'Tels': '(55)5277-1888',
#   'Terreno': 139,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 139,
#   'direccion': '292808_Colorado-departamento-Venta"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 4972000.0,
#   'Tels': '(55)5291-1500',
#   'Terreno': 113,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte',
#   'construccion': 113,
#   'direccion': '275769_NUEVO-EN-PLANTA-BAJA"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4950000.0,
#   'Tels': '(55)1107-8717',
#   'Terreno': 97,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 97,
#   'direccion': '299053_LUZ-SAVIÑON-725"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 4850000.0,
#   'Tels': '(55)5292-7256 / (55)5292-7257',
#   'Terreno': 120,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Santa Maria Nonoalco',
#   'construccion': 120,
#   'direccion': '298321_"Parque-Andrea-Residencial"-Hermoso-departamento-de-3-recamaras',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 4800000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 120,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Poniente',
#   'construccion': 60,
#   'direccion': '301248_EXCELENTE-PENTHOUSE-EN-VENTA-AV.-DR.-VERTIZ"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4750000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Gral. Pedro María Anaya',
#   'construccion': 102,
#   'direccion': '292261_Departamento-en-venta%252C-General-Anaya%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4720000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 116,
#   'direccion': '302342_Departamento-en-venta%252C-Del-Valle%252C-Benito-Juárez"',
#   'n_banios': 3,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 4680000.0,
#   'Tels': '(55)5119-1003/ (55)5119-1001',
#   'Terreno': 85,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'San Juan',
#   'construccion': 85,
#   'direccion': '298656_RAV---1693.-Departamento-en-Venta-colonia-San-Juan-en-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4500000.0,
#   'Tels': '(55)1664-6750',
#   'Terreno': 113,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'San Pedro De Los Pinos',
#   'construccion': 113,
#   'direccion': '282762_San-Pedro-de-los-Pinos-Vendo-Hermoso-departamento"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4500000.0,
#   'Tels': '(722)277-8333',
#   'Terreno': 118,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 118,
#   'direccion': '293979_Departamento-en-Venta-en-La-Colonia-Napolés-en-la-Ciudad-de-México%252C-PRECIO-A-NEGOCIAR!!!"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 4500000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 98,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Poniente',
#   'construccion': 98,
#   'direccion': '295488_DEPARTAMENTO-EN-VENTA%252C-COL.-VERTIZ-NARVARTE%252C-BENITO-JUAREZ"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 4500000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 76,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Xoco',
#   'construccion': 83,
#   'direccion': '297499_Excelente-departamento-en-venta"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4500000.0,
#   'Tels': '(55)9154-0127',
#   'Terreno': 108,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Sur',
#   'construccion': 108,
#   'direccion': '301188_DEPARTAMENTO-EN-VENTA-BENITO-JUAREZ"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 4450000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 146,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Alamos',
#   'construccion': 120,
#   'direccion': '296472_Penthouse-en-venta"',
#   'n_banios': 3,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 4400000.0,
#   'Tels': '(55)1251-9900',
#   'Terreno': 100,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Acacias',
#   'construccion': 100,
#   'direccion': '291212_En-Calle-Cerrada-a-2-cuadras-de-Plaza-Coyoacan"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 4400000.0,
#   'Tels': '(55)1251-9900',
#   'Terreno': 100,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Sur',
#   'construccion': 100,
#   'direccion': '291213_En-Calle-Cerrada-a-2-cuadras-de-Plaza-Coyoacan"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 4400000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 76,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 76,
#   'direccion': '293462_DEPARTAMENTO-EN-VENTA%252C-COL.-NÁPOLES%252C-BENITO-JUÁREZ."',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 4350000.0,
#   'Tels': '(55)9154-0127',
#   'Terreno': 96,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 96,
#   'direccion': '286593_Departamento-en-Venta-Col.-Del-Valle"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4300000.0,
#   'Tels': '(55)2124-8076',
#   'Terreno': 90,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Norte',
#   'construccion': 90,
#   'direccion': '285933_DEPARTAMENTO-EN-VENTA-EN-ZONA-CENTRICA"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4300000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 117,
#   'direccion': '303865_Departamento-en-venta%252C-Del-Valle%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 4300000.0,
#   'Tels': '(55)5652-5202',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Letran Valle',
#   'construccion': 94,
#   'direccion': '306231_Departamento-en-Venta-ubicado-en-Av.-Cuauhtémoc-y-Pilares"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4255000.0,
#   'Tels': '(55) 5511 2853',
#   'Terreno': 130,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 130,
#   'direccion': '290451_OPORTUNIDAD-ÚNICA-DEPARTAMENTO-A-UNOS-PASOS-DEL-METRO-INSURGENTES-SUR-Y-METROBUS-FÉLIX-CUEVAS"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 4250000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Santa Cruz Atoyac',
#   'construccion': 75,
#   'direccion': '280405_Departamento-en-venta%252C-Santa-Cruz-Atoyac%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 4200000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 140,
#   'direccion': '274622_Departamento-en-venta%252C-Del-Valle-Centro%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 4200000.0,
#   'Tels': '(55)3869-1070',
#   'Terreno': 112,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': None,
#   'direccion': '283061_Nápoles.-Excelente-departamento-de-2-niveles"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 4200000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Acacias',
#   'construccion': 74,
#   'direccion': '303375_Departamento-en-venta-en-Acacias"',
#   'n_banios': 1,
#   'n_estacionam': 0,
#   'n_recamaras': 1},
#  {'Precio': 4200000.0,
#   'Tels': '(55)1517-3591 / (55)5421-9381',
#   'Terreno': 88,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Santa Cruz Atoyac',
#   'construccion': 88,
#   'direccion': '306587_Venta-departamento-en-la-Benito-Juarez"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 4100000.0,
#   'Tels': '(55)2455-1166 / (55)2455-1167 / (55)2455-1168',
#   'Terreno': 98,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Vértiz Narvarte',
#   'construccion': 98,
#   'direccion': '276795_Departamento-en-venta-en-la-Colonia-Vertiz-Narvarte"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4100000.0,
#   'Tels': '(55)2455-1166 / (55)2455-1167 / (55)2455-1168',
#   'Terreno': 98,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Vértiz Narvarte',
#   'construccion': 98,
#   'direccion': '276797_Departamentos-en-la-Colonia-Vertiz-Narvarte"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4100000.0,
#   'Tels': '(55)2455-1166 / (55)2455-1167 / (55)2455-1168',
#   'Terreno': 98,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Vértiz Narvarte',
#   'construccion': 98,
#   'direccion': '276798_Departamentos-en-la-Colonia-Vertiz-Narvarte"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 4100000.0,
#   'Tels': '(55)3869-1070',
#   'Terreno': 94,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Santa Maria Nonoalco',
#   'construccion': None,
#   'direccion': '295438_Santa-Maria-Nonoalco.-Excelente-departamento"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 3995000.0,
#   'Tels': '(55)2455-1166 / (55)2455-1167 / (55)2455-1168',
#   'Terreno': 115,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Tlacoquemécatl Del Valle',
#   'construccion': 115,
#   'direccion': '270223_Departamento-en-venta-Col.-Tlacoquemécatl"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3995000.0,
#   'Tels': '(55)5291-1500',
#   'Terreno': 161,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 161,
#   'direccion': '291185_OPORTUNIDAD-EN-LA-DEL-VALLE"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3995000.0,
#   'Tels': '(55)5590-0840',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'San Pedro De Los Pinos',
#   'construccion': 135,
#   'direccion': '301928_Propiedad-en-venta"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3850000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Sur',
#   'construccion': 74,
#   'direccion': '292278_Departamento-en-venta%252C-Del-Valle%252C-Acacias%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3850000.0,
#   'Tels': '(55)5084-0265',
#   'Terreno': 118,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Oriente',
#   'construccion': 118,
#   'direccion': '299202_PRECIOSO-DEPARTAMENTO-DE-LUJO"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 3850000.0,
#   'Tels': '(55)1107-8717',
#   'Terreno': 105,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Gral. Pedro María Anaya',
#   'construccion': 105,
#   'direccion': '300242_GENERAL-RINCON"',
#   'n_banios': 2,
#   'n_estacionam': 4,
#   'n_recamaras': 3},
#  {'Precio': 3800000.0,
#   'Tels': '(55)5255-5521 con 4 líneas',
#   'Terreno': 100,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Piedad Narvarte',
#   'construccion': 100,
#   'direccion': '257072_Departamento-en-Venta"',
#   'n_banios': 3,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3800000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Ciudad De Los Deportes',
#   'construccion': 110,
#   'direccion': '305479_Departamento-en-venta%252C-Ciudad-de-los-Deportes%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3700000.0,
#   'Tels': '(55)5662-9700',
#   'Terreno': 76,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Portales',
#   'construccion': 76,
#   'direccion': '297076_Departamento-Venta---Portales"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 3680000.0,
#   'Tels': '(55)2455-1166 / (55)2455-1167 / (55)2455-1168',
#   'Terreno': 105,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Tlacoquemécatl Del Valle',
#   'construccion': 105,
#   'direccion': '256955_Departamento-en-Venta-en-la-mejor-zona-de-Del-Valle"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3651400.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 84,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Alamos',
#   'construccion': 84,
#   'direccion': '286082_Exclusivo-departamento-en-Preventa"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 3650000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Sur',
#   'construccion': 74,
#   'direccion': '292277_Departamento-en-venta%252C-Del-Valle%252C-Acacias%252C-Benito-Juárez"',
#   'n_banios': 1,
#   'n_estacionam': 0,
#   'n_recamaras': 1},
#  {'Precio': 3600000.0,
#   'Tels': '(55)2124-8076',
#   'Terreno': 85,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Extremadura Insurgentes',
#   'construccion': 85,
#   'direccion': '288780_Bonito-departamento-cerca-de-Parque-hundido"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3600000.0,
#   'Tels': '(55)7592-8626',
#   'Terreno': 85,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Poniente',
#   'construccion': 85,
#   'direccion': '298452_Excelente-Departamento-de-oportunidad."',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 3590000.0,
#   'Tels': '(55)1107-8717',
#   'Terreno': 68,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 68,
#   'direccion': '297852_LUZ-SAVIÑON-814"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 3590000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 89,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Oriente',
#   'construccion': 89,
#   'direccion': '301132_Departamento-en-venta"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3550000.0,
#   'Tels': '(55)5603-3434',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Portales',
#   'construccion': 129,
#   'direccion': '304353_Se-Vende-Departamento-en-Col.-Portales-Norte"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3540000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 92,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Alamos',
#   'construccion': 92,
#   'direccion': '286084_Exclusivo-departamento-en-Preventa"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 3500000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 95,
#   'direccion': '289329_Departamento-en-venta%252C-Del-Valle%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3500000.0,
#   'Tels': '(55)5550-2880',
#   'Terreno': 70,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 70,
#   'direccion': '303243_Departamento-en-venta-Colonia-Del-Valle-Centro"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3420000.0,
#   'Tels': '(55)5652-5202',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 62,
#   'direccion': '302753_Departamento-en-la-del-Valle"',
#   'n_banios': 1,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3400000.0,
#   'Tels': '(55)1664-6750',
#   'Terreno': 90,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Alamos',
#   'construccion': None,
#   'direccion': '281575_Vendo-Departamento-Semi-Nuevo-Colonia-Álamos"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 3400000.0,
#   'Tels': '(55)5550-2880',
#   'Terreno': 85,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': '8 De Agosto',
#   'construccion': 85,
#   'direccion': '297455_Departamento-con-excelente-ubicación-en-zona-aledaña-a-San-Pedro-de-los-Pinos"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3400000.0,
#   'Tels': '(55)1107-8717',
#   'Terreno': 104,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte',
#   'construccion': 104,
#   'direccion': '303104_CUAUHTEMOC-872"',
#   'n_banios': 3,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 3400000.0,
#   'Tels': '(55)1107-8717',
#   'Terreno': 109,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Independencia',
#   'construccion': 90,
#   'direccion': '305729_CUMBRES-DE-MALTRATA"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 3390000.0,
#   'Tels': '(55)5606-0606',
#   'Terreno': 88,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Piedad Narvarte',
#   'construccion': 88,
#   'direccion': '234318_VENTA-DEPARTAMENTO-EN-NARVARTE-NUEVO"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3370000.0,
#   'Tels': '(55)3869-1070',
#   'Terreno': 107,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'San Pedro De Los Pinos',
#   'construccion': None,
#   'direccion': '302921_San-Pedro-De-Los-Pinos.Departamento-en-primer-Nivel"',
#   'n_banios': 1,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3350000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 91,
#   'direccion': '288066_Departamento-en-venta%252C-Napoles%252C-Benito-Juárez"',
#   'n_banios': 1,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3350000.0,
#   'Tels': '(55)2455-1166 / (55)2455-1167 / (55)2455-1168',
#   'Terreno': 86,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte',
#   'construccion': 86,
#   'direccion': '299739_Departamento-en-venta-en-la-Colonia-Narvarte"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3350000.0,
#   'Tels': '(55)6843-8870 / (55)6843-8871 / (55)6843-8872',
#   'Terreno': 84,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Zacahuizco',
#   'construccion': 84,
#   'direccion': '305820_Hermoso-Departamento-en-VENTA-en-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3340000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 84,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Alamos',
#   'construccion': 84,
#   'direccion': '286085_Exclusivo-departamento-en-Preventa"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3330000.0,
#   'Tels': '(55)6546-2569 / (55)6546-2571',
#   'Terreno': 64,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Alamos',
#   'construccion': 64,
#   'direccion': '286086_Exclusivo-departamento-en-Preventa"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3325000.0,
#   'Tels': '(55)5662-9700',
#   'Terreno': 65,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Josefa Ortiz De Domínguez',
#   'construccion': 65,
#   'direccion': '288424_Penthouse-en-Venta"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 3300000.0,
#   'Tels': '(55)5291-1500',
#   'Terreno': 115,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Miravalle',
#   'construccion': 115,
#   'direccion': '288791_PARA-ESTRENAR-departamento-en-Benito-Juarez"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 2},
#  {'Precio': 3300000.0,
#   'Tels': '(55)5531-0115 / (55)5531-0112',
#   'Terreno': 98,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 98,
#   'direccion': '295832_Depto.-Venta-ubicadísimo%252C-a-unos-pasos-de-World-Trade-Center%252C-Insurgentes-Sur-y-Viaducto-Rio-Becerra"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3300000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'San José Insurgentes',
#   'construccion': 67,
#   'direccion': '299856_Departamento-en-venta%252C-San-José-Insurgentes%252C-Benito-Juárez"',
#   'n_banios': 1,
#   'n_estacionam': 1,
#   'n_recamaras': 1},
#  {'Precio': 3300000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Oriente',
#   'construccion': 100,
#   'direccion': '304241_Departamento-en-venta%252C-Narvarte%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3290000.0,
#   'Tels': '(55)5531-0115 / (55)5531-0112',
#   'Terreno': 92,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nonoalco',
#   'construccion': 92,
#   'direccion': '293786_Departamento-en-venta-muy-iluminado-con-excelente-ubicación"',
#   'n_banios': 1,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3250000.0,
#   'Tels': '(55) 5511 2853',
#   'Terreno': 109,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Independencia',
#   'construccion': 109,
#   'direccion': '299198_Amplio-departamento-en-la-Colonia-Independencia%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 2,
#   'n_recamaras': 3},
#  {'Precio': 3200000.0,
#   'Tels': '(55)4744-9328',
#   'Terreno': 78,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Oriente',
#   'construccion': None,
#   'direccion': '291476_HERMOSO-DEPARTAMENTO-UBICADO-A-2-CUADRAS-DE-PARQUE-DELTA"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3200000.0,
#   'Tels': '(55)5603-3434',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 71,
#   'direccion': '299737_Se-Vende-Departamento-en-Col.-del-valle"',
#   'n_banios': 1,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 3150000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Nápoles',
#   'construccion': 83,
#   'direccion': '269292_Departamento-en-venta%252C-Nápoles%252C-Benito-Juárez"',
#   'n_banios': 1,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 3080000.0,
#   'Tels': '+52 (55) 5084-0392',
#   'Terreno': 66,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 66,
#   'direccion': '302692_EXCELENTE-DEPARTAMENTO-EN-VENTA"',
#   'n_banios': 1,
#   'n_estacionam': 1,
#   'n_recamaras': 1},
#  {'Precio': 2985000.0,
#   'Tels': '(55)2455-1166 / (55)2455-1167 / (55)2455-1168',
#   'Terreno': 90,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle',
#   'construccion': 90,
#   'direccion': '276624_Departamento-en-Venta-en-Colonia-Del-Valle"',
#   'n_banios': 1,
#   'n_estacionam': 1,
#   'n_recamaras': 3},
#  {'Precio': 2980000.0,
#   'Tels': '(55)6585-3607 / (55)6585-3608',
#   'Terreno': 69,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Narvarte Poniente',
#   'construccion': 69,
#   'direccion': '288381_Departamento-en-Venta-Narvarte-Poniente!!!!!"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 2970000.0,
#   'Tels': '(55)5523-2099',
#   'Terreno': 0,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Del Valle Centro',
#   'construccion': 80,
#   'direccion': '292281_Departamento-en-venta%252C-Del-Valle%252C-Benito-Juárez"',
#   'n_banios': 2,
#   'n_estacionam': 1,
#   'n_recamaras': 2},
#  {'Precio': 2953525.0,
#   'Tels': '(55)5255-3232',
#   'Terreno': 61,
#   'alcaldia': 'Benito Juárez',
#   'ciudad': 'Ciudad De México',
#   'colonia': 'Santa Maria Nonoalco',
#   'construccion': 61,
#   'direccion': '289328_Departamento-Col.-Nonoalco%252C-en-PREVENTA%252C"',
#   'n_banios': 1,
#   'n_estacionam': 1,
#   'n_recamaras': 2}]

# %%
l=[]
base_url="https://www.pythonhow.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/t=0&s="
for page in range(0,int(page_nr)*10,10):
    print( )
    r=requests.get(base_url+str(page)+".html")
    c=r.content
    #c=r.json()["list"]
    soup=BeautifulSoup(c,"html.parser")
    all=soup.find_all("div",{"class":"propertyRow"})
    for item in all:
        d={}
        d["Address"]=item.find_all("span",{"class","propAddressCollapse"})[0].text
        try:
            d["Locality"]=item.find_all("span",{"class","propAddressCollapse"})[1].text
        except:
            d["Locality"]=None
        d["Price"]=item.find("h4",{"class","propPrice"}).text.replace("\n","").replace(" ","")
        try:
            d["Beds"]=item.find("span",{"class","infoBed"}).find("b").text
        except:
            d["Beds"]=None
    
        try:
            d["Area"]=item.find("span",{"class","infoSqFt"}).find("b").text
        except:
            d["Area"]=None
    
        try:
            d["Full Baths"]=item.find("span",{"class","infoValueFullBath"}).find("b").text
        except:
            d["Full Baths"]=None

        try:
            d["Half Baths"]=item.find("span",{"class","infoValueHalfBath"}).find("b").text
        except:
            d["Half Baths"]=None
        for column_group in item.find_all("div",{"class":"columnGroup"}):
            for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span",{"class":"featureName"})):
                if "Lot Size" in feature_group.text:
                    d["Lot Size"]=feature_name.text
        l.append(d)

# %%
l
# Out:
# [{'Address': '0 Gateway',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$725,000'},
#  {'Address': '1003 Winchester Blvd.',
#   'Area': None,
#   'Beds': '4',
#   'Full Baths': '4',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': '0.21 Acres',
#   'Price': '$452,900'},
#  {'Address': '600 Talladega',
#   'Area': '3,154',
#   'Beds': '5',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Price': '$396,900'},
#  {'Address': '3239 Spearhead Way',
#   'Area': '3,076',
#   'Beds': '4',
#   'Full Baths': '3',
#   'Half Baths': '1',
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': 'Under 1/2 Acre, ',
#   'Price': '$389,900'},
#  {'Address': '522 Emerald Street',
#   'Area': '1,172',
#   'Beds': '3',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': 'Under 1/2 Acre, ',
#   'Price': '$254,000'},
#  {'Address': "1302 Veteran's Drive",
#   'Area': '1,932',
#   'Beds': '4',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': '0.27 Acres',
#   'Price': '$252,900'},
#  {'Address': '1021 Cypress Cir',
#   'Area': '1,676',
#   'Beds': '4',
#   'Full Baths': '3',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': 'Under 1/2 Acre, ',
#   'Price': '$210,000'},
#  {'Address': '913 Madison Dr',
#   'Area': '1,344',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': 'Under 1/2 Acre, ',
#   'Price': '$209,000'},
#  {'Address': '1344 Teton Street',
#   'Area': '1,920',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': 'Under 1/2 Acre, ',
#   'Price': '$199,900'},
#  {'Address': '4 Minnies Lane',
#   'Area': '1,664',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Rock Springs, WY 82901',
#   'Lot Size': '2.02 Acres',
#   'Price': '$196,900'},
#  {'Address': '9339 Sd 26900',
#   'Area': '2,560',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$1,700,000'},
#  {'Address': 'RR674P13 Hwy 377',
#   'Area': '2,000',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$1,100,000'},
#  {'Address': '0 Hwy 41',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$1,080,000'},
#  {'Address': '9339 Sd 26900',
#   'Area': '2,560',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$908,350'},
#  {'Address': 'CR450 Hwy 377',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$905,000'},
#  {'Address': 'Cr 240 Cr 240',
#   'Area': '1,398',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$695,000'},
#  {'Address': 'RR674 Hwy 377',
#   'Area': '1,738',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$605,000'},
#  {'Address': '9770a Sd 26900',
#   'Area': '1,080',
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$559,805'},
#  {'Address': 'Lot17 CR 2630',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$504,000'},
#  {'Address': 'Tr12,16 CR 520',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Rocksprings, TX 78880',
#   'Price': '$410,000'},
#  {'Address': '32575 S Shadow Mountain Road',
#   'Area': '2,318',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$299,900'},
#  {'Address': '32750 S Shangrila Drive',
#   'Area': '2,120',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$167,500'},
#  {'Address': '0000 Black Canyon Highway',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Lot Size': '5 Acres',
#   'Price': '$150,000'},
#  {'Address': '34775 S CHOLLA Drive',
#   'Area': '1,220',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$129,500'},
#  {'Address': '33403 S. HA-WA-SI TERRACE',
#   'Area': '2,000',
#   'Beds': '4',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'BLACK CANYON CITY, AZ 85324',
#   'Price': '$129,000'},
#  {'Address': '34263 S Bertha Street',
#   'Area': '2,260',
#   'Beds': '5',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$80,000'},
#  {'Address': '33160 S Canyon Road',
#   'Area': '1,248',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$77,900'},
#  {'Address': '19421 E Todd Evans Road',
#   'Area': '1,404',
#   'Beds': '3',
#   'Full Baths': '2',
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$70,500'},
#  {'Address': '18688 E AGUA Vista',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Lot Size': '0.7 Acres',
#   'Price': '$70,000'},
#  {'Address': '50600 N Old Black Canyon Road',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Lot Size': '3 Acres',
#   'Price': '$67,500'},
#  {'Address': '20101 E SQUAW VALLEY Road',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$54,900'},
#  {'Address': '33259 S Canyon Road',
#   'Area': '1,056',
#   'Beds': '3',
#   'Full Baths': '1',
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Price': '$45,600'},
#  {'Address': '34558 S ROADRUNNER RD',
#   'Area': '784',
#   'Beds': '2',
#   'Full Baths': '1',
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Lot Size': 'Under 1/2 Acre',
#   'Price': '$40,000'},
#  {'Address': '19260 E Scenic Loop Road',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Lot Size': '2.35 Acres',
#   'Price': '$30,000'},
#  {'Address': '19000 E MAREN Avenue',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Lot Size': '2.05 Acres',
#   'Price': '$29,000'},
#  {'Address': '19350 E SAGUARO Drive',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Lot Size': '0.73 Acres',
#   'Price': '$28,995'},
#  {'Address': '20650 E Amethyst Place',
#   'Area': None,
#   'Beds': None,
#   'Full Baths': None,
#   'Half Baths': None,
#   'Locality': 'Black Canyon City, AZ 85324',
#   'Lot Size': '0.31 Acres',
#   'Price': '$15,000'}]

# %%
import pandas
df=pandas.DataFrame(l)

# %%
df
# Out:
#          Precio                                           Tels  Terreno  \
# 0    16500000.0                                  (55)1107-8717      410
# 1    15500000.0                                  (55)1251-9900      370
# 2    15000000.0                                  (55)5523-2099        0
# 3    13845000.0  (55)6843-8870 / (55)6843-8871 / (55)6843-8872
# 98   303243_Departamento-en-venta-Colonia-Del-Valle...         2
# 99                302753_Departamento-en-la-del-Valle"         1
# 100  281575_Vendo-Departamento-Semi-Nuevo-Colonia-Á...         2
# 101  297455_Departamento-con-excelente-ubicación-en...         2
# 102                             303104_CUAUHTEMOC-872"         3
# 103                        305729_CUMBRES-DE-MALTRATA"         2
# 104       234318_VENTA-DEPARTAMENTO-EN-NARVARTE-NUEVO"         2
# 105  302921_San-Pedro-De-Los-Pinos.Departamento-en-...         1
# 106  288066_Departamento-en-venta%252C-Napoles%252C...         1
# 107  299739_Departamento-en-venta-en-la-Colonia-Nar...         2
# 108  305820_Hermoso-Departamento-en-VENTA-en-Benito...         2
# 109         286085_Exclusivo-departamento-en-Preventa"         2
# 110         286086_Exclusivo-departamento-en-Preventa"         2
# 111                         288424_Penthouse-en-Venta"         2
# 112  288791_PARA-ESTRENAR-departamento-en-Benito-Ju...         2
# 113  295832_Depto.-Venta-ubicadísimo%252C-a-unos-pa...         2
# 114  299856_Departamento-en-venta%252C-San-José-Ins...         1
# 115  304241_Departamento-en-venta%252C-Narvarte%252...         2
# 116  293786_Departamento-en-venta-muy-iluminado-con...         1
# 117  299198_Amplio-departamento-en-la-Colonia-Indep...         2
# 118  291476_HERMOSO-DEPARTAMENTO-UBICADO-A-2-CUADRA...         2
# 119    299737_Se-Vende-Departamento-en-Col.-del-valle"         1
# 120  269292_Departamento-en-venta%252C-Nápoles%252C...         1
# 121            302692_EXCELENTE-DEPARTAMENTO-EN-VENTA"         1
# 122  276624_Departamento-en-Venta-en-Colonia-Del-Va...         1
# 123  288381_Departamento-en-Venta-Narvarte-Poniente...         2
# 124  292281_Departamento-en-venta%252C-Del-Valle%25...         2
# 125  289328_Departamento-Col.-Nonoalco%252C-en-PREV...         1
#
#      n_estacionam  n_recamaras
# 0               2            4
# 1               2            4
# 2               4            3
# 3               2            2
# 4               2            3
# 5               2            3
# 6               3            4
# 7               2            2
# 8               2            5
# 9               2            2
# 10              2            2
# 11              3            3
# 12              2            2
# 13              3            3
# 14              2            2
# 15              2            2
# 16              2            2
# 17              3            3
# 18              2            3
# 19              2            3
# 20              2            3
# 21              3            2
# 22              2            3
# 23              2            3
# 24              2            2
# 25              1            3
# 26              2            3
# 27              2            2
# 28              2            3
# 29              2            3
# ..            ...          ...
# 96              2            2
# 97              1            3
# 98              1            2
# 99              1            2
# 100             2            3
# 101             1            2
# 102             2            3
# 103             2            2
# 104             1            2
# 105             1            2
# 106             1            3
# 107             1            2
# 108             1            3
# 109             1            2
# 110             1            2
# 111             2            2
# 112             2            2
# 113             1            3
# 114             1            1
# 115             1            2
# 116             1            2
# 117             2            3
# 118             1            2
# 119             1            3
# 120             1            2
# 121             1            1
# 122             1            3
# 123             1            2
# 124             1            2
# 125             1            2
#
# [126 rows x 11 columns]

# %%
df.to_csv("Output.csv")

# %%
int(page_nr)
# Out:
# 6

# %%
21*6
# Out:
# 126
